# %% [markdown]
# ### Pandas:

# %%
# Pandas is a Python library, which is used to analyze data.
#It has functions for analyzing, cleaning, exploring, and manipulating data.
#The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.
#Pandas gives you answers about the data. Like:

#Is there a correlation between two or more columns?
#What is average value?
#Max value?
#Min value?
#Pandas are also able to delete rows that are not relevant, or contains wrong values, like empty or NULL values. 
#This is called cleaning the data.

# %%
import pandas as pd

# Now Pandas is imported and ready to use.

# %% [markdown]
# ### Pandas Series

# %%
# A Pandas Series is like a column in a table. It is a one-dimensional array holding data of any type.

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
# If nothing else is specified, the values are labeled with their index number. 
#First value has index 0, second value has index 1 etc.

print(myvar[0])
# Out:
# 1

# %%
# With the index argument, you can name your own labels.

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
# When you have created labels, you can access an item by referring to the label.

print(myvar["y"])
# Out:
# 7

# %%
# You can also use a key/value object, like a dictionary, when creating a Series.

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.

# Series is like a column, a DataFrame is the whole table.

# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.



mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
# Pandas use the loc attribute to return one or more specified row(s)


print(myvar.loc[0])
# Out:
# cars        BMW
# passings      3
# Name: 0, dtype: object

# %%
print(myvar.loc[[0, 1]])
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7

# %%
# With the index argument, you can name your own indexes.


data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
# Use the named index in the loc attribute to return the specified row(s).

#refer to the named index:
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# ## Load Files Into a DataFrame

# %%
import pandas as pd

df = pd.read_csv('Data_Set.csv')

print(df)
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0           CASH                         2                              4
# 1        PAYMENT                         3                              4
# 2        PAYMENT                         3                              4
# 3        PAYMENT                         3                              4
# 4           CASH                         5                              4
# ...          ...                       ...                            ...
# 180514  TRANSFER                         6                              4
# 180515     DEBIT                         2                              4
# 180516     DEBIT                         3                              4
# 180517   PAYMENT                         4                              4
# 180518      CASH                         1                              0
#
#         Benefit per order  Sales per customer   Delivery Status  \
# 0               88.790001          239.979996  Advance shipping
# 1               91.180000          193.990005  Advance shipping
# 2               36.470001          107.889999  Advance shipping
# 3               68.250000          227.500000  Advance shipping
# 4                4.100000           40.980000     Late delivery
# ...                   ...                 ...               ...
# 180514        -107.959999          161.869995     Late delivery
# 180515        -126.559998          172.660004  Advance shipping
# 180516          91.250000          314.640015  Advance shipping
# 180517           1.530000           10.910000  Shipping on time
# 180518           9.790000           34.980000     Late delivery
#
#         Late_delivery_risk  Category Id     Category Name Customer City  ...  \
# 0                        0           43  Camping & Hiking       Hickory  ...
# 1                        0           48      Water Sports       Chicago  ...
# 2                        0           18    Men's Footwear       Chicago  ...
# 3                        0           24   Women's Apparel       Chicago  ...
# 4                        1           40       Accessories   San Antonio  ...
# ...                    ...          ...               ...           ...  ...
# 180514                   1           76  Women's Clothing        Caguas  ...
# 180515                   0           76  Women's Clothing    Plainfield  ...
# 180516                   0           73    Sporting Goods        Caguas  ...
# 180517                   0           74              Toys        Berwyn  ...
# 180518                   1           75       Video Games         Miami  ...
#
#        Order Zipcode Product Card Id Product Category Id  Product Description  \
# 0                NaN             957                  43                  NaN
# 1                NaN            1073                  48                  NaN
# 2                NaN             403                  18                  NaN
# 3                NaN             502                  24                  NaN
# 4                NaN             897                  40                  NaN
# ...              ...             ...                 ...                  ...
# 180514           NaN            1363                  76                  NaN
# 180515           NaN            1363                  76                  NaN
# 180516           NaN            1360                  73                  NaN
# 180517           NaN            1361                  74                  NaN
# 180518           NaN            1362                  75                  NaN
#
#                                             Product Image  \
# 0       http://images.acmesports.sports/Diamondback+Wo...
# 1       http://images.acmesports.sports/Pelican+Sunstr...
# 2       http://images.acmesports.sports/Nike+Men%27s+C...
# 3       http://images.acmesports.sports/Nike+Men%27s+D...
# 4       http://images.acmesports.sports/Team+Golf+New+...
# ...                                                   ...
# 180514     http://images.acmesports.sports/Summer+dresses
# 180515     http://images.acmesports.sports/Summer+dresses
# 180516       http://images.acmesports.sports/Smart+watch
# 180517              http://images.acmesports.sports/Toys
# 180518  http://images.acmesports.sports/Fighting+video...
#
#                                          Product Name Product Price  \
# 0       Diamondback Women's Serene Classic Comfort Bi    299.980011
# 1                         Pelican Sunstream 100 Kayak    199.990005
# 2             Nike Men's CJ Elite 2 TD Football Cleat    129.990005
# 3                Nike Men's Dri-FIT Victory Golf Polo     50.000000
# 4          Team Golf New England Patriots Putter Grip     24.990000
# ...                                               ...           ...
# 180514                                 Summer dresses    215.820007
# 180515                                 Summer dresses    215.820007
# 180516                                   Smart watch     327.750000
# 180517                                          Toys      11.540000
# 180518                           Fighting video games     39.750000
#
#        Product Status shipping date (DateOrders)   Shipping Mode
# 0                   0           01/03/2015 00:00  Standard Class
# 1                   0           01/04/2015 00:21  Standard Class
# 2                   0           01/04/2015 00:21  Standard Class
# 3                   0           01/04/2015 00:21  Standard Class
# 4                   0           01/06/2015 01:03  Standard Class
# ...               ...                        ...             ...
# 180514              0           02/06/2018 22:14  Standard Class
# 180515              0           02/02/2018 22:35  Standard Class
# 180516              0           02/03/2018 22:56  Standard Class
# 180517              0           02/04/2018 23:17  Standard Class
# 180518              0           02/01/2018 11:38        Same Day
#
# [180519 rows x 53 columns]

# %%
# One of the most used method for getting a quick overview of the DataFrame, is the head() method.

# The head() method returns the headers and a specified number of rows, starting from the top.

print(df.head(5))
# Out:
#       Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     CASH                         2                              4
# 1  PAYMENT                         3                              4
# 2  PAYMENT                         3                              4
# 3  PAYMENT                         3                              4
# 4     CASH                         5                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          88.790001          239.979996  Advance shipping
# 1          91.180000          193.990005  Advance shipping
# 2          36.470001          107.889999  Advance shipping
# 3          68.250000          227.500000  Advance shipping
# 4           4.100000           40.980000     Late delivery
#
#    Late_delivery_risk  Category Id     Category Name Customer City  ...  \
# 0                   0           43  Camping & Hiking       Hickory  ...
# 1                   0           48      Water Sports       Chicago  ...
# 2                   0           18    Men's Footwear       Chicago  ...
# 3                   0           24   Women's Apparel       Chicago  ...
# 4                   1           40       Accessories   San Antonio  ...
#
#   Order Zipcode Product Card Id Product Category Id  Product Description  \
# 0           NaN             957                  43                  NaN
# 1           NaN            1073                  48                  NaN
# 2           NaN             403                  18                  NaN
# 3           NaN             502                  24                  NaN
# 4           NaN             897                  40                  NaN
#
#                                        Product Image  \
# 0  http://images.acmesports.sports/Diamondback+Wo...
# 1  http://images.acmesports.sports/Pelican+Sunstr...
# 2  http://images.acmesports.sports/Nike+Men%27s+C...
# 3  http://images.acmesports.sports/Nike+Men%27s+D...
# 4  http://images.acmesports.sports/Team+Golf+New+...
#
#                                     Product Name Product Price Product Status  \
# 0  Diamondback Women's Serene Classic Comfort Bi    299.980011              0
# 1                    Pelican Sunstream 100 Kayak    199.990005              0
# 2        Nike Men's CJ Elite 2 TD Football Cleat    129.990005              0
# 3           Nike Men's Dri-FIT Victory Golf Polo     50.000000              0
# 4     Team Golf New England Patriots Putter Grip     24.990000              0
#
#   shipping date (DateOrders)   Shipping Mode
# 0           01/03/2015 00:00  Standard Class
# 1           01/04/2015 00:21  Standard Class
# 2           01/04/2015 00:21  Standard Class
# 3           01/04/2015 00:21  Standard Class
# 4           01/06/2015 01:03  Standard Class
#
# [5 rows x 53 columns]

# %%
# There is also a tail() method for viewing the last rows of the DataFrame.

# The tail() method returns the headers and a specified number of rows, starting from the bottom.

print(df.tail())
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 180514  TRANSFER                         6                              4
# 180515     DEBIT                         2                              4
# 180516     DEBIT                         3                              4
# 180517   PAYMENT                         4                              4
# 180518      CASH                         1                              0
#
#         Benefit per order  Sales per customer   Delivery Status  \
# 180514        -107.959999          161.869995     Late delivery
# 180515        -126.559998          172.660004  Advance shipping
# 180516          91.250000          314.640015  Advance shipping
# 180517           1.530000           10.910000  Shipping on time
# 180518           9.790000           34.980000     Late delivery
#
#         Late_delivery_risk  Category Id     Category Name Customer City  ...  \
# 180514                   1           76  Women's Clothing        Caguas  ...
# 180515                   0           76  Women's Clothing    Plainfield  ...
# 180516                   0           73    Sporting Goods        Caguas  ...
# 180517                   0           74              Toys        Berwyn  ...
# 180518                   1           75       Video Games         Miami  ...
#
#        Order Zipcode Product Card Id Product Category Id  Product Description  \
# 180514           NaN            1363                  76                  NaN
# 180515           NaN            1363                  76                  NaN
# 180516           NaN            1360                  73                  NaN
# 180517           NaN            1361                  74                  NaN
# 180518           NaN            1362                  75                  NaN
#
#                                             Product Image  \
# 180514     http://images.acmesports.sports/Summer+dresses
# 180515     http://images.acmesports.sports/Summer+dresses
# 180516       http://images.acmesports.sports/Smart+watch
# 180517              http://images.acmesports.sports/Toys
# 180518  http://images.acmesports.sports/Fighting+video...
#
#                 Product Name Product Price Product Status  \
# 180514        Summer dresses    215.820007              0
# 180515        Summer dresses    215.820007              0
# 180516          Smart watch     327.750000              0
# 180517                 Toys      11.540000              0
# 180518  Fighting video games     39.750000              0
#
#        shipping date (DateOrders)   Shipping Mode
# 180514           02/06/2018 22:14  Standard Class
# 180515           02/02/2018 22:35  Standard Class
# 180516           02/03/2018 22:56  Standard Class
# 180517           02/04/2018 23:17  Standard Class
# 180518           02/01/2018 11:38        Same Day
#
# [5 rows x 53 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
#  12  Customer Fname                 180519 non-null  object
#  13  Customer Id                    180519 non-null  int64
#  14  Customer Lname                 180511 non-null  object
#  15  Customer Password              180519 non-null  object
#  16  Customer Segment               180519 non-null  object
#  17  Customer State                 180519 non-null  object
#  18  Customer Street                180519 non-null  object
#  19  Customer Zipcode               180516 non-null  float64
#  20  Department Id                  180519 non-null  int64
#  21  Department Name                180519 non-null  object
#  22  Latitude                       180519 non-null  float64
#  23  Longitude                      180519 non-null  float64
#  24  Market                         180519 non-null  object
#  25  Order City                     180519 non-null  object
#  26  Order Country                  180519 non-null  object
#  27  Order Customer Id              180519 non-null  int64
#  28  order date (DateOrders)        180519 non-null  object
#  29  Order Id                       180519 non-null  int64
#  30  Order Item Cardprod Id         180519 non-null  int64
#  31  Order Item Discount            180519 non-null  float64
#  32  Order Item Discount Rate       180519 non-null  float64
#  33  Order Item Id                  180519 non-null  int64
#  34  Order Item Product Price       180519 non-null  float64
#  35  Order Item Profit Ratio        180519 non-null  float64
#  36  Order Item Quantity            180519 non-null  int64
#  37  Sales                          180519 non-null  float64
#  38  Order Item Total               180519 non-null  float64
#  39  Order Profit Per Order         180519 non-null  float64
#  40  Order Region                   180519 non-null  object
#  41  Order State                    180519 non-null  object
#  42  Order Status                   180519 non-null  object
#  43  Order Zipcode                  24840 non-null   float64
#  44  Product Card Id                180519 non-null  int64
#  45  Product Category Id            180519 non-null  int64
#  46  Product Description            0 non-null       float64
#  47  Product Image                  180519 non-null  object
#  48  Product Name                   180519 non-null  object
#  49  Product Price                  180519 non-null  float64
#  50  Product Status                 180519 non-null  int64
#  51  shipping date (DateOrders)     180519 non-null  object
#  52  Shipping Mode                  180519 non-null  object
# dtypes: float64(15), int64(14), object(24)
# memory usage: 73.0+ MB
# None

# %%
df.pop("Product Description")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
#  12  Customer Fname                 180519 non-null  object
#  13  Customer Id                    180519 non-null  int64
#  14  Customer Lname                 180511 non-null  object
#  15  Customer Password              180519 non-null  object
#  16  Customer Segment               180519 non-null  object
#  17  Customer State                 180519 non-null  object
#  18  Customer Street                180519 non-null  object
#  19  Customer Zipcode               180516 non-null  float64
#  20  Department Id                  180519 non-null  int64
#  21  Department Name                180519 non-null  object
#  22  Latitude                       180519 non-null  float64
#  23  Longitude                      180519 non-null  float64
#  24  Market                         180519 non-null  object
#  25  Order City                     180519 non-null  object
#  26  Order Country                  180519 non-null  object
#  27  Order Customer Id              180519 non-null  int64
#  28  order date (DateOrders)        180519 non-null  object
#  29  Order Id                       180519 non-null  int64
#  30  Order Item Cardprod Id         180519 non-null  int64
#  31  Order Item Discount            180519 non-null  float64
#  32  Order Item Discount Rate       180519 non-null  float64
#  33  Order Item Id                  180519 non-null  int64
#  34  Order Item Product Price       180519 non-null  float64
#  35  Order Item Profit Ratio        180519 non-null  float64
#  36  Order Item Quantity            180519 non-null  int64
#  37  Sales                          180519 non-null  float64
#  38  Order Item Total               180519 non-null  float64
#  39  Order Profit Per Order         180519 non-null  float64
#  40  Order Region                   180519 non-null  object
#  41  Order State                    180519 non-null  object
#  42  Order Status                   180519 non-null  object
#  43  Order Zipcode                  24840 non-null   float64
#  44  Product Card Id                180519 non-null  int64
#  45  Product Category Id            180519 non-null  int64
#  46  Product Image                  180519 non-null  object
#  47  Product Name                   180519 non-null  object
#  48  Product Price                  180519 non-null  float64
#  49  Product Status                 180519 non-null  int64
#  50  shipping date (DateOrders)     180519 non-null  object
#  51  Shipping Mode                  180519 non-null  object
# dtypes: float64(14), int64(14), object(24)
# memory usage: 71.6+ MB
# None

# %%
# One way to deal with empty cells is to remove rows that contain empty cells.

# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.

new_df = df.dropna()
print(new_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24840 entries, 78230 to 103069
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Type                           24840 non-null  object
#  1   Days for shipping (real)       24840 non-null  int64
#  2   Days for shipment (scheduled)  24840 non-null  int64
#  3   Benefit per order              24840 non-null  float64
#  4   Sales per customer             24840 non-null  float64
#  5   Delivery Status                24840 non-null  object
#  6   Late_delivery_risk             24840 non-null  int64
#  7   Category Id                    24840 non-null  int64
#  8   Category Name                  24840 non-null  object
#  9   Customer City                  24840 non-null  object
#  10  Customer Country               24840 non-null  object
#  11  Customer Email                 24840 non-null  object
#  12  Customer Fname                 24840 non-null  object
#  13  Customer Id                    24840 non-null  int64
#  14  Customer Lname                 24840 non-null  object
#  15  Customer Password              24840 non-null  object
#  16  Customer Segment               24840 non-null  object
#  17  Customer State                 24840 non-null  object
#  18  Customer Street                24840 non-null  object
#  19  Customer Zipcode               24840 non-null  float64
#  20  Department Id                  24840 non-null  int64
#  21  Department Name                24840 non-null  object
#  22  Latitude                       24840 non-null  float64
#  23  Longitude                      24840 non-null  float64
#  24  Market                         24840 non-null  object
#  25  Order City                     24840 non-null  object
#  26  Order Country                  24840 non-null  object
#  27  Order Customer Id              24840 non-null  int64
#  28  order date (DateOrders)        24840 non-null  object
#  29  Order Id                       24840 non-null  int64
#  30  Order Item Cardprod Id         24840 non-null  int64
#  31  Order Item Discount            24840 non-null  float64
#  32  Order Item Discount Rate       24840 non-null  float64
#  33  Order Item Id                  24840 non-null  int64
#  34  Order Item Product Price       24840 non-null  float64
#  35  Order Item Profit Ratio        24840 non-null  float64
#  36  Order Item Quantity            24840 non-null  int64
#  37  Sales                          24840 non-null  float64
#  38  Order Item Total               24840 non-null  float64
#  39  Order Profit Per Order         24840 non-null  float64
#  40  Order Region                   24840 non-null  object
#  41  Order State                    24840 non-null  object
#  42  Order Status                   24840 non-null  object
#  43  Order Zipcode                  24840 non-null  float64
#  44  Product Card Id                24840 non-null  int64
#  45  Product Category Id            24840 non-null  int64
#  46  Product Image                  24840 non-null  object
#  47  Product Name                   24840 non-null  object
#  48  Product Price                  24840 non-null  float64
#  49  Product Status                 24840 non-null  int64
#  50  shipping date (DateOrders)     24840 non-null  object
#  51  Shipping Mode                  24840 non-null  object
# dtypes: float64(14), int64(14), object(24)
# memory usage: 10.0+ MB
# None

# %%
print(new_df["Order Zipcode"])
# Out:
# 78230     42420.0
# 78231     42420.0
# 78232     42420.0
# 78233     42420.0
# 78234     42420.0
#            ...
# 103065    92627.0
# 103066    92627.0
# 103067    92627.0
# 103068    92627.0
# 103069    92627.0
# Name: Order Zipcode, Length: 24840, dtype: float64

# %%
print(df["Order Zipcode"])
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 180514   NaN
# 180515   NaN
# 180516   NaN
# 180517   NaN
# 180518   NaN
# Name: Order Zipcode, Length: 180519, dtype: float64

# %%
# To replace empty values for one column, specify the column name for the DataFrame

df["Order Zipcode"].fillna("empty", inplace = True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
#  12  Customer Fname                 180519 non-null  object
#  13  Customer Id                    180519 non-null  int64
#  14  Customer Lname                 180511 non-null  object
#  15  Customer Password              180519 non-null  object
#  16  Customer Segment               180519 non-null  object
#  17  Customer State                 180519 non-null  object
#  18  Customer Street                180519 non-null  object
#  19  Customer Zipcode               180516 non-null  float64
#  20  Department Id                  180519 non-null  int64
#  21  Department Name                180519 non-null  object
#  22  Latitude                       180519 non-null  float64
#  23  Longitude                      180519 non-null  float64
#  24  Market                         180519 non-null  object
#  25  Order City                     180519 non-null  object
#  26  Order Country                  180519 non-null  object
#  27  Order Customer Id              180519 non-null  int64
#  28  order date (DateOrders)        180519 non-null  object
#  29  Order Id                       180519 non-null  int64
#  30  Order Item Cardprod Id         180519 non-null  int64
#  31  Order Item Discount            180519 non-null  float64
#  32  Order Item Discount Rate       180519 non-null  float64
#  33  Order Item Id                  180519 non-null  int64
#  34  Order Item Product Price       180519 non-null  float64
#  35  Order Item Profit Ratio        180519 non-null  float64
#  36  Order Item Quantity            180519 non-null  int64
#  37  Sales                          180519 non-null  float64
#  38  Order Item Total               180519 non-null  float64
#  39  Order Profit Per Order         180519 non-null  float64
#  40  Order Region                   180519 non-null  object
#  41  Order State                    180519 non-null  object
#  42  Order Status                   180519 non-null  object
#  43  Order Zipcode                  180519 non-null  object
#  44  Product Card Id                180519 non-null  int64
#  45  Product Category Id            180519 non-null  int64
#  46  Product Image                  180519 non-null  object
#  47  Product Name                   180519 non-null  object
#  48  Product Price                  180519 non-null  float64
#  49  Product Status                 180519 non-null  int64
#  50  shipping date (DateOrders)     180519 non-null  object
#  51  Shipping Mode                  180519 non-null  object
# dtypes: float64(13), int64(14), object(25)
# memory usage: 71.6+ MB
# None

# %%
# A common way to replace empty cells, is to calculate the mean, median or mode value of the column.

# Pandas uses the mean() median() and mode() methods to calculate the respective values for a specified column

x = df["Benefit per order"].mean()
print(x)
df["Benefit per order"].fillna(x, inplace = True)
# Out:
# 21.974988638593807

# %%
# Let's try to convert all cells in the 'shipping date (DateOrders)' column into dates.

# Pandas has a to_datetime() method for this:

print(df['shipping date (DateOrders)'])
# Out:
# 0         01/03/2015 00:00
# 1         01/04/2015 00:21
# 2         01/04/2015 00:21
# 3         01/04/2015 00:21
# 4         01/06/2015 01:03
#                 ...
# 180514    02/06/2018 22:14
# 180515    02/02/2018 22:35
# 180516    02/03/2018 22:56
# 180517    02/04/2018 23:17
# 180518    02/01/2018 11:38
# Name: shipping date (DateOrders), Length: 180519, dtype: object

# %%
df['shipping date (DateOrders)']=pd.to_datetime(df['shipping date (DateOrders)'])
print(df['shipping date (DateOrders)'])
# Out:
# 0        2015-01-03 00:00:00
# 1        2015-01-04 00:21:00
# 2        2015-01-04 00:21:00
# 3        2015-01-04 00:21:00
# 4        2015-01-06 01:03:00
#                  ...
# 180514   2018-02-06 22:14:00
# 180515   2018-02-02 22:35:00
# 180516   2018-02-03 22:56:00
# 180517   2018-02-04 23:17:00
# 180518   2018-02-01 11:38:00
# Name: shipping date (DateOrders), Length: 180519, dtype: datetime64[ns]

# %% [markdown]
# ## Wrong Data

# %%
#"Wrong data" does not have to be "empty cells" or "wrong format", it can just be wrong, like if someone registered "199" instead of "1.99".

#Sometimes you can spot wrong data by looking at the data set, because you have an expectation of what it should be. Here the
# third customer id is wrong

print(df["Customer Id"])
# Out:
# 0         11599
# 1           256
# 2           256
# 3           256
# 4          8827
#           ...
# 180514    20753
# 180515    20754
# 180516    20755
# 180517    20756
# 180518    20757
# Name: Customer Id, Length: 180519, dtype: int64

# %%
df.loc[3, "Customer Id"] = 45
print(df["Customer Id"])
print(df.index)
# Out:
# 0         11599
# 1           256
# 2           256
# 3            45
# 4          8827
#           ...
# 180514    20753
# 180515    20754
# 180516    20755
# 180517    20756
# 180518    20757
# Name: Customer Id, Length: 180519, dtype: int64
# RangeIndex(start=0, stop=180519, step=1)

# %%
# Loop through all values in the "Product Price" column.

# If the value is higher than 250, set it to 245

print(df["Product Price"])
# Out:
# 0         299.980011
# 1         199.990005
# 2         129.990005
# 3          50.000000
# 4          24.990000
#              ...
# 180514    215.820007
# 180515    215.820007
# 180516    327.750000
# 180517     11.540000
# 180518     39.750000
# Name: Product Price, Length: 180519, dtype: float64

# %%
for x in df.index:
    if df.loc[x, "Product Price"] > 250:
        df.loc[x, "Product Price"] = 245
        
print(df["Product Price"])
# Out:
# 0         245.000000
# 1         199.990005
# 2         129.990005
# 3          50.000000
# 4          24.990000
#              ...
# 180514    215.820007
# 180515    215.820007
# 180516    245.000000
# 180517     11.540000
# 180518     39.750000
# Name: Product Price, Length: 180519, dtype: float64

# %%
# Removing Rows:
# Delete rows where "Product Price" is bigger than 240:

for x in df.index:
    if df.loc[x, "Product Price"] > 240:
        df.drop(x, inplace = True)
        
print(df["Product Price"])
print(df.info())
# Out:
# 1         199.990005
# 2         129.990005
# 3          50.000000
# 4          24.990000
# 5          50.000000
#              ...
# 180512    215.820007
# 180513    215.820007
# 180514    215.820007
# 180515    215.820007
# 180518     39.750000
# Name: Product Price, Length: 141288, dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141288 entries, 1 to 180518
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           141288 non-null  object
#  1   Days for shipping (real)       141288 non-null  int64
#  2   Days for shipment (scheduled)  141288 non-null  int64
#  3   Benefit per order              141288 non-null  float64
#  4   Sales per customer             141288 non-null  float64
#  5   Delivery Status                141288 non-null  object
#  6   Late_delivery_risk             141288 non-null  int64
#  7   Category Id                    141288 non-null  int64
#  8   Category Name                  141288 non-null  object
#  9   Customer City                  141288 non-null  object
#  10  Customer Country               141288 non-null  object
#  11  Customer Email                 141288 non-null  object
#  12  Customer Fname                 141288 non-null  object
#  13  Customer Id                    141288 non-null  int64
#  14  Customer Lname                 141286 non-null  object
#  15  Customer Password              141288 non-null  object
#  16  Customer Segment               141288 non-null  object
#  17  Customer State                 141288 non-null  object
#  18  Customer Street                141288 non-null  object
#  19  Customer Zipcode               141287 non-null  float64
#  20  Department Id                  141288 non-null  int64
#  21  Department Name                141288 non-null  object
#  22  Latitude                       141288 non-null  float64
#  23  Longitude                      141288 non-null  float64
#  24  Market                         141288 non-null  object
#  25  Order City                     141288 non-null  object
#  26  Order Country                  141288 non-null  object
#  27  Order Customer Id              141288 non-null  int64
#  28  order date (DateOrders)        141288 non-null  object
#  29  Order Id                       141288 non-null  int64
#  30  Order Item Cardprod Id         141288 non-null  int64
#  31  Order Item Discount            141288 non-null  float64
#  32  Order Item Discount Rate       141288 non-null  float64
#  33  Order Item Id                  141288 non-null  int64
#  34  Order Item Product Price       141288 non-null  float64
#  35  Order Item Profit Ratio        141288 non-null  float64
#  36  Order Item Quantity            141288 non-null  int64
#  37  Sales                          141288 non-null  float64
#  38  Order Item Total               141288 non-null  float64
#  39  Order Profit Per Order         141288 non-null  float64
#  40  Order Region                   141288 non-null  object
#  41  Order State                    141288 non-null  object
#  42  Order Status                   141288 non-null  object
#  43  Order Zipcode                  141288 non-null  object
#  44  Product Card Id                141288 non-null  int64
#  45  Product Category Id            141288 non-null  int64
#  46  Product Image                  141288 non-null  object
#  47  Product Name                   141288 non-null  object
#  48  Product Price                  141288 non-null  float64
#  49  Product Status                 141288 non-null  int64
#  50  shipping date (DateOrders)     141288 non-null  datetime64[ns]
#  51  Shipping Mode                  141288 non-null  object
# dtypes: datetime64[ns](1), float64(13), int64(14), object(24)
# memory usage: 61.2+ MB
# None

# %%
# Discovering Duplicates
# To remove duplicates, use the drop_duplicates() method.

df.drop_duplicates(inplace = True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141288 entries, 1 to 180518
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           141288 non-null  object
#  1   Days for shipping (real)       141288 non-null  int64
#  2   Days for shipment (scheduled)  141288 non-null  int64
#  3   Benefit per order              141288 non-null  float64
#  4   Sales per customer             141288 non-null  float64
#  5   Delivery Status                141288 non-null  object
#  6   Late_delivery_risk             141288 non-null  int64
#  7   Category Id                    141288 non-null  int64
#  8   Category Name                  141288 non-null  object
#  9   Customer City                  141288 non-null  object
#  10  Customer Country               141288 non-null  object
#  11  Customer Email                 141288 non-null  object
#  12  Customer Fname                 141288 non-null  object
#  13  Customer Id                    141288 non-null  int64
#  14  Customer Lname                 141286 non-null  object
#  15  Customer Password              141288 non-null  object
#  16  Customer Segment               141288 non-null  object
#  17  Customer State                 141288 non-null  object
#  18  Customer Street                141288 non-null  object
#  19  Customer Zipcode               141287 non-null  float64
#  20  Department Id                  141288 non-null  int64
#  21  Department Name                141288 non-null  object
#  22  Latitude                       141288 non-null  float64
#  23  Longitude                      141288 non-null  float64
#  24  Market                         141288 non-null  object
#  25  Order City                     141288 non-null  object
#  26  Order Country                  141288 non-null  object
#  27  Order Customer Id              141288 non-null  int64
#  28  order date (DateOrders)        141288 non-null  object
#  29  Order Id                       141288 non-null  int64
#  30  Order Item Cardprod Id         141288 non-null  int64
#  31  Order Item Discount            141288 non-null  float64
#  32  Order Item Discount Rate       141288 non-null  float64
#  33  Order Item Id                  141288 non-null  int64
#  34  Order Item Product Price       141288 non-null  float64
#  35  Order Item Profit Ratio        141288 non-null  float64
#  36  Order Item Quantity            141288 non-null  int64
#  37  Sales                          141288 non-null  float64
#  38  Order Item Total               141288 non-null  float64
#  39  Order Profit Per Order         141288 non-null  float64
#  40  Order Region                   141288 non-null  object
#  41  Order State                    141288 non-null  object
#  42  Order Status                   141288 non-null  object
#  43  Order Zipcode                  141288 non-null  object
#  44  Product Card Id                141288 non-null  int64
#  45  Product Category Id            141288 non-null  int64
#  46  Product Image                  141288 non-null  object
#  47  Product Name                   141288 non-null  object
#  48  Product Price                  141288 non-null  float64
#  49  Product Status                 141288 non-null  int64
#  50  shipping date (DateOrders)     141288 non-null  datetime64[ns]
#  51  Shipping Mode                  141288 non-null  object
# dtypes: datetime64[ns](1), float64(13), int64(14), object(24)
# memory usage: 57.1+ MB
# None

# %%
# The Result of the corr() method is a table with a lot of numbers that represents how well the relationship is between two columns.

# The number varies from -1 to 1.

# 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.

# 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.

# -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.

# 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.

df.corr()
# Out:
#                                Days for shipping (real)  \
# Days for shipping (real)                       1.000000
# Days for shipment (scheduled)                  0.517473
# Benefit per order                             -0.004513
# Sales per customer                            -0.000692
# Late_delivery_risk                             0.400392
# Category Id                                   -0.001463
# Customer Id                                    0.002589
# Customer Zipcode                              -0.000730
# Department Id                                 -0.001375
# Latitude                                      -0.002066
# Longitude                                      0.005319
# Order Customer Id                              0.002589
# Order Id                                      -0.002326
# Order Item Cardprod Id                        -0.002032
# Order Item Discount                            0.001787
# Order Item Discount Rate                       0.002305
# Order Item Id                                 -0.002372
# Order Item Product Price                      -0.000852
# Order Item Profit Ratio                       -0.004296
# Order Item Quantity                           -0.000572
# Sales                                         -0.000308
# Order Item Total                              -0.000692
# Order Profit Per Order                        -0.004513
# Product Card Id                               -0.002032
# Product Category Id                           -0.001463
# Product Price                                 -0.000852
# Product Status                                      NaN
#
#                                Days for shipment (scheduled)  \
# Days for shipping (real)                            0.517473
# Days for shipment (scheduled)                       1.000000
# Benefit per order                                   0.000683
# Sales per customer                                  0.001052
# Late_delivery_risk                                 -0.368768
# Category Id                                        -0.003044
# Customer Id                                        -0.001050
# Customer Zipcode                                   -0.004589
# Department Id                                      -0.002197
# Latitude                                           -0.006830
# Longitude                                           0.005045
# Order Customer Id                                  -0.001049
# Order Id                                           -0.001160
# Order Item Cardprod Id                             -0.003245
# Order Item Discount                                 0.000800
# Order Item Discount Rate                            0.000893
# Order Item Id                                      -0.001089
# Order Item Product Price                            0.000757
# Order Item Profit Ratio                            -0.001627
# Order Item Quantity                                -0.001463
# Sales                                               0.001103
# Order Item Total                                    0.001052
# Order Profit Per Order                              0.000683
# Product Card Id                                    -0.003245
# Product Category Id                                -0.003044
# Product Price                                       0.000757
# Product Status                                           NaN
#
#                                Benefit per order  Sales per customer  \
# Days for shipping (real)               -0.004513           -0.000692
# Days for shipment (scheduled)           0.000683            0.001052
# Benefit per order                       1.000000            0.118150
# Sales per customer                      0.118150            1.000000
# Late_delivery_risk                     -0.004049           -0.004724
# Category Id                            -0.019367           -0.151330
# Customer Id                            -0.005905           -0.042510
# Customer Zipcode                        0.001003           -0.004686
# Department Id                          -0.021001           -0.164084
# Latitude                                0.000602           -0.001202
# Longitude                              -0.001266            0.003151
# Order Customer Id                      -0.005904           -0.042510
# Order Id                                0.004548           -0.004218
# Order Item Cardprod Id                 -0.019528           -0.150065
# Order Item Discount                     0.048521            0.418056
# Order Item Discount Rate               -0.019684           -0.144706
# Order Item Id                           0.004811           -0.002328
# Order Item Product Price                0.020802            0.204068
# Order Item Profit Ratio                 0.871016           -0.001166
# Order Item Quantity                     0.078601            0.637993
# Sales                                   0.116390            0.986441
# Order Item Total                        0.118150            1.000000
# Order Profit Per Order                  1.000000            0.118150
# Product Card Id                        -0.019528           -0.150065
# Product Category Id                    -0.019367           -0.151330
# Product Price                           0.020802            0.204068
# Product Status                               NaN                 NaN
#
#                                Late_delivery_risk  Category Id  Customer Id  \
# Days for shipping (real)                 0.400392    -0.001463     0.002589
# Days for shipment (scheduled)           -0.368768    -0.003044    -0.001050
# Benefit per order                       -0.004049    -0.019367    -0.005905
# Sales per customer                      -0.004724    -0.151330    -0.042510
# Late_delivery_risk                       1.000000     0.002071     0.002133
# Category Id                              0.002071     1.000000     0.195300
# Customer Id                              0.002133     0.195300     1.000000
# Customer Zipcode                         0.002324     0.002462     0.004629
# Department Id                            0.001438     0.936558     0.111280
# Latitude                                 0.003641     0.001812     0.002796
# Longitude                               -0.001010    -0.001636    -0.007519
# Order Customer Id                        0.002132     0.195300     1.000000
# Order Id                                -0.002527     0.132133     0.125975
# Order Item Cardprod Id                   0.001947     0.991439     0.157188
# Order Item Discount                     -0.000878    -0.085799    -0.021181
# Order Item Discount Rate                 0.000686     0.000812     0.003110
# Order Item Id                           -0.002619     0.122515     0.116092
# Order Item Product Price                -0.003358     0.219370     0.032931
# Order Item Profit Ratio                 -0.001998    -0.003701    -0.002193
# Order Item Quantity                     -0.000258    -0.150662    -0.063455
# Sales                                   -0.004461    -0.153350    -0.042550
# Order Item Total                        -0.004724    -0.151330    -0.042510
# Order Profit Per Order                  -0.004049    -0.019367    -0.005905
# Product Card Id                          0.001947     0.991439     0.157188
# Product Category Id                      0.002071     1.000000     0.195300
# Product Price                           -0.003358     0.219370     0.032931
# Product Status                                NaN          NaN          NaN
#
#                                Customer Zipcode  Department Id  Latitude  ...  \
# Days for shipping (real)              -0.000730      -0.001375 -0.002066  ...
# Days for shipment (scheduled)         -0.004589      -0.002197 -0.006830  ...
# Benefit per order                      0.001003      -0.021001  0.000602  ...
# Sales per customer                    -0.004686      -0.164084 -0.001202  ...
# Late_delivery_risk                     0.002324       0.001438  0.003641  ...
# Category Id                            0.002462       0.936558  0.001812  ...
# Customer Id                            0.004629       0.111280  0.002796  ...
# Customer Zipcode                       1.000000       0.001606  0.585236  ...
# Department Id                          0.001606       1.000000  0.001691  ...
# Latitude                               0.585236       0.001691  1.000000  ...
# Longitude                             -0.924416      -0.001493 -0.526184  ...
# Order Customer Id                      0.004630       0.111280  0.002796  ...
# Order Id                              -0.001875       0.082855 -0.003847  ...
# Order Item Cardprod Id                 0.002311       0.944919  0.001483  ...
# Order Item Discount                   -0.004759      -0.093262 -0.005977  ...
# Order Item Discount Rate              -0.001758       0.000441 -0.006401  ...
# Order Item Id                         -0.001951       0.077666 -0.003920  ...
# Order Item Product Price               0.000915       0.133436 -0.000906  ...
# Order Item Profit Ratio                0.002496      -0.004006 -0.000695  ...
# Order Item Quantity                   -0.005689      -0.105442 -0.001915  ...
# Sales                                 -0.005128      -0.166316 -0.002174  ...
# Order Item Total                      -0.004686      -0.164084 -0.001202  ...
# Order Profit Per Order                 0.001003      -0.021001  0.000602  ...
# Product Card Id                        0.002311       0.944919  0.001483  ...
# Product Category Id                    0.002462       0.936558  0.001812  ...
# Product Price                          0.000915       0.133436 -0.000906  ...
# Product Status                              NaN            NaN       NaN  ...
#
#                                Order Item Product Price  \
# Days for shipping (real)                      -0.000852
# Days for shipment (scheduled)                  0.000757
# Benefit per order                              0.020802
# Sales per customer                             0.204068
# Late_delivery_risk                            -0.003358
# Category Id                                    0.219370
# Customer Id                                    0.032931
# Customer Zipcode                               0.000915
# Department Id                                  0.133436
# Latitude                                      -0.000906
# Longitude                                      0.000341
# Order Customer Id                              0.032930
# Order Id                                       0.060373
# Order Item Cardprod Id                         0.237665
# Order Item Discount                            0.116350
# Order Item Discount Rate                       0.000096
# Order Item Id                                  0.058826
# Order Item Product Price                       1.000000
# Order Item Profit Ratio                       -0.003332
# Order Item Quantity                           -0.520036
# Sales                                          0.206909
# Order Item Total                               0.204068
# Order Profit Per Order                         0.020802
# Product Card Id                                0.237665
# Product Category Id                            0.219370
# Product Price                                  1.000000
# Product Status                                      NaN
#
#                                Order Item Profit Ratio  Order Item Quantity  \
# Days for shipping (real)                     -0.004296            -0.000572
# Days for shipment (scheduled)                -0.001627            -0.001463
# Benefit per order                             0.871016             0.078601
# Sales per customer                           -0.001166             0.637993
# Late_delivery_risk                           -0.001998            -0.000258
# Category Id                                  -0.003701            -0.150662
# Customer Id                                  -0.002193            -0.063455
# Customer Zipcode                              0.002496            -0.005689
# Department Id                                -0.004006            -0.105442
# Latitude                                     -0.000695            -0.001915
# Longitude                                    -0.002772             0.003704
# Order Customer Id                            -0.002193            -0.063454
# Order Id                                      0.003412            -0.059885
# Order Item Cardprod Id                       -0.003572            -0.156712
# Order Item Discount                          -0.002476             0.362981
# Order Item Discount Rate                     -0.002271             0.000057
# Order Item Id                                 0.003538            -0.057048
# Order Item Product Price                     -0.003332            -0.520036
# Order Item Profit Ratio                       1.000000             0.001276
# Order Item Quantity                           0.001276             1.000000
# Sales                                        -0.001509             0.646733
# Order Item Total                             -0.001166             0.637993
# Order Profit Per Order                        0.871016             0.078601
# Product Card Id                              -0.003572            -0.156712
# Product Category Id                          -0.003701            -0.150662
# Product Price                                -0.003332            -0.520036
# Product Status                                     NaN                  NaN
#
#                                   Sales  Order Item Total  \
# Days for shipping (real)      -0.000308         -0.000692
# Days for shipment (scheduled)  0.001103          0.001052
# Benefit per order              0.116390          0.118150
# Sales per customer             0.986441          1.000000
# Late_delivery_risk            -0.004461         -0.004724
# Category Id                   -0.153350         -0.151330
# Customer Id                   -0.042550         -0.042510
# Customer Zipcode              -0.005128         -0.004686
# Department Id                 -0.166316         -0.164084
# Latitude                      -0.002174         -0.001202
# Longitude                      0.003703          0.003151
# Order Customer Id             -0.042550         -0.042510
# Order Id                      -0.004214         -0.004218
# Order Item Cardprod Id        -0.152006         -0.150065
# Order Item Discount            0.561472          0.418056
# Order Item Discount Rate      -0.000065         -0.144706
# Order Item Id                 -0.002301         -0.002328
# Order Item Product Price       0.206909          0.204068
# Order Item Profit Ratio       -0.001509         -0.001166
# Order Item Quantity            0.646733          0.637993
# Sales                          1.000000          0.986441
# Order Item Total               0.986441          1.000000
# Order Profit Per Order         0.116390          0.118150
# Product Card Id               -0.152006         -0.150065
# Product Category Id           -0.153350         -0.151330
# Product Price                  0.206909          0.204068
# Product Status                      NaN               NaN
#
#                                Order Profit Per Order  Product Card Id  \
# Days for shipping (real)                    -0.004513        -0.002032
# Days for shipment (scheduled)                0.000683        -0.003245
# Benefit per order                            1.000000        -0.019528
# Sales per customer                           0.118150        -0.150065
# Late_delivery_risk                          -0.004049         0.001947
# Category Id                                 -0.019367         0.991439
# Customer Id                                 -0.005905         0.157188
# Customer Zipcode                             0.001003         0.002311
# Department Id                               -0.021001         0.944919
# Latitude                                     0.000602         0.001483
# Longitude                                   -0.001266        -0.001615
# Order Customer Id                           -0.005904         0.157188
# Order Id                                     0.004548         0.104318
# Order Item Cardprod Id                      -0.019528         1.000000
# Order Item Discount                          0.048521        -0.084740
# Order Item Discount Rate                    -0.019684         0.001038
# Order Item Id                                0.004811         0.096797
# Order Item Product Price                     0.020802         0.237665
# Order Item Profit Ratio                      0.871016        -0.003572
# Order Item Quantity                          0.078601        -0.156712
# Sales                                        0.116390        -0.152006
# Order Item Total                             0.118150        -0.150065
# Order Profit Per Order                       1.000000        -0.019528
# Product Card Id                             -0.019528         1.000000
# Product Category Id                         -0.019367         0.991439
# Product Price                                0.020802         0.237665
# Product Status                                    NaN              NaN
#
#                                Product Category Id  Product Price  \
# Days for shipping (real)                 -0.001463      -0.000852
# Days for shipment (scheduled)            -0.003044       0.000757
# Benefit per order                        -0.019367       0.020802
# Sales per customer                       -0.151330       0.204068
# Late_delivery_risk                        0.002071      -0.003358
# Category Id                               1.000000       0.219370
# Customer Id                               0.195300       0.032931
# Customer Zipcode                          0.002462       0.000915
# Department Id                             0.936558       0.133436
# Latitude                                  0.001812      -0.000906
# Longitude                                -0.001636       0.000341
# Order Customer Id                         0.195300       0.032930
# Order Id                                  0.132133       0.060373
# Order Item Cardprod Id                    0.991439       0.237665
# Order Item Discount                      -0.085799       0.116350
# Order Item Discount Rate                  0.000812       0.000096
# Order Item Id                             0.122515       0.058826
# Order Item Product Price                  0.219370       1.000000
# Order Item Profit Ratio                  -0.003701      -0.003332
# Order Item Quantity                      -0.150662      -0.520036
# Sales                                    -0.153350       0.206909
# Order Item Total                         -0.151330       0.204068
# Order Profit Per Order                   -0.019367       0.020802
# Product Card Id                           0.991439       0.237665
# Product Category Id                       1.000000       0.219370
# Product Price                             0.219370       1.000000
# Product Status                                 NaN            NaN
#
#                                Product Status
# Days for shipping (real)                  NaN
# Days for shipment (scheduled)             NaN
# Benefit per order                         NaN
# Sales per customer                        NaN
# Late_delivery_risk                        NaN
# Category Id                               NaN
# Customer Id                               NaN
# Customer Zipcode                          NaN
# Department Id                             NaN
# Latitude                                  NaN
# Longitude                                 NaN
# Order Customer Id                         NaN
# Order Id                                  NaN
# Order Item Cardprod Id                    NaN
# Order Item Discount                       NaN
# Order Item Discount Rate                  NaN
# Order Item Id                             NaN
# Order Item Product Price                  NaN
# Order Item Profit Ratio                   NaN
# Order Item Quantity                       NaN
# Sales                                     NaN
# Order Item Total                          NaN
# Order Profit Per Order                    NaN
# Product Card Id                           NaN
# Product Category Id                       NaN
# Product Price                             NaN
# Product Status                            NaN
#
# [27 rows x 27 columns]
